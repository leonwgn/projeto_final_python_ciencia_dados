# %% [markdown]
# # Install Jupyter Notebook
#
# Install Jupyter Notebook using pip or conda, ensuring the environment is set up correctly.

# %% [markdown]
# # Create a New Workspace Directory
#
# Use command-line tools to create a new directory for the workspace and navigate into it.

# %% [markdown]
# # Launch Jupyter Notebook
#
# Run the command to launch Jupyter Notebook from the workspace directory.

# %% [markdown]
# # Create a New Notebook
#
# In the Jupyter interface, create a new notebook file within the workspace.

# %%
print("Teste jupyter notebook")
# Out:
# Teste jupyter notebook
